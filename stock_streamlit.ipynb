# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('../yfinance_Project/Stocl.L.csv')

# %%
df
# Out:
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2025-01-02   588.326904   588.465864   566.929539
# 1              1  2025-01-03   584.927368   588.126983   580.527890
# 2              2  2025-01-06   569.929199   579.927957   558.330664
# 3              3  2025-01-07   576.528320   580.031913   565.529687
# 4              4  2025-01-08   577.928162   584.327391   572.128895
# ...          ...         ...          ...          ...          ...
# 2781         274  2026-02-02  3246.000000  3262.000000  3150.000000
# 2782         275  2026-02-03  3354.000000  3354.000000  3268.000000
# 2783         276  2026-02-04  3342.000000  3400.000000  3320.000000
# 2784         277  2026-02-05  3374.000000  3404.000000  3326.000000
# 2785         278  2026-02-06  3402.000000  3424.000000  3356.000000
#
#              Open    Volume                 Stock
# 0      568.929291  16730522  ROLLS ROYCE HOLDINGS
# 1      587.127107   6438560  ROLLS ROYCE HOLDINGS
# 2      579.727970  19109873  ROLLS ROYCE HOLDINGS
# 3      569.729178  16269992  ROLLS ROYCE HOLDINGS
# 4      574.328633  12009385  ROLLS ROYCE HOLDINGS
# ...           ...       ...                   ...
# 2781  3192.000000   2200400        THE WEIR GROUP
# 2782  3282.000000    671442        THE WEIR GROUP
# 2783  3364.000000    758328        THE WEIR GROUP
# 2784  3334.000000   2294577        THE WEIR GROUP
# 2785  3366.000000    578372        THE WEIR GROUP
#
# [2786 rows x 8 columns]

# %%
df=df.drop('Unnamed: 0' , axis =1)

# %%
df
# Out:
#             Date        Close         High          Low         Open  \
# 0     2025-01-02   588.326904   588.465864   566.929539   568.929291
# 1     2025-01-03   584.927368   588.126983   580.527890   587.127107
# 2     2025-01-06   569.929199   579.927957   558.330664   579.727970
# 3     2025-01-07   576.528320   580.031913   565.529687   569.729178
# 4     2025-01-08   577.928162   584.327391   572.128895   574.328633
# ...          ...          ...          ...          ...          ...
# 2781  2026-02-02  3246.000000  3262.000000  3150.000000  3192.000000
# 2782  2026-02-03  3354.000000  3354.000000  3268.000000  3282.000000
# 2783  2026-02-04  3342.000000  3400.000000  3320.000000  3364.000000
# 2784  2026-02-05  3374.000000  3404.000000  3326.000000  3334.000000
# 2785  2026-02-06  3402.000000  3424.000000  3356.000000  3366.000000
#
#         Volume                 Stock
# 0     16730522  ROLLS ROYCE HOLDINGS
# 1      6438560  ROLLS ROYCE HOLDINGS
# 2     19109873  ROLLS ROYCE HOLDINGS
# 3     16269992  ROLLS ROYCE HOLDINGS
# 4     12009385  ROLLS ROYCE HOLDINGS
# ...        ...                   ...
# 2781   2200400        THE WEIR GROUP
# 2782    671442        THE WEIR GROUP
# 2783    758328        THE WEIR GROUP
# 2784   2294577        THE WEIR GROUP
# 2785    578372        THE WEIR GROUP
#
# [2786 rows x 7 columns]

# %%
df.dtypes
# Out:
# Date       object
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# Stock      object
# dtype: object

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
df
# Out:
#            Date        Close         High          Low         Open    Volume  \
# 0    2025-01-02   588.326904   588.465864   566.929539   568.929291  16730522
# 1    2025-01-03   584.927368   588.126983   580.527890   587.127107   6438560
# 2    2025-01-06   569.929199   579.927957   558.330664   579.727970  19109873
# 3    2025-01-07   576.528320   580.031913   565.529687   569.729178  16269992
# 4    2025-01-08   577.928162   584.327391   572.128895   574.328633  12009385
# ...         ...          ...          ...          ...          ...       ...
# 2781 2026-02-02  3246.000000  3262.000000  3150.000000  3192.000000   2200400
# 2782 2026-02-03  3354.000000  3354.000000  3268.000000  3282.000000    671442
# 2783 2026-02-04  3342.000000  3400.000000  3320.000000  3364.000000    758328
# 2784 2026-02-05  3374.000000  3404.000000  3326.000000  3334.000000   2294577
# 2785 2026-02-06  3402.000000  3424.000000  3356.000000  3366.000000    578372
#
#                      Stock
# 0     ROLLS ROYCE HOLDINGS
# 1     ROLLS ROYCE HOLDINGS
# 2     ROLLS ROYCE HOLDINGS
# 3     ROLLS ROYCE HOLDINGS
# 4     ROLLS ROYCE HOLDINGS
# ...                    ...
# 2781        THE WEIR GROUP
# 2782        THE WEIR GROUP
# 2783        THE WEIR GROUP
# 2784        THE WEIR GROUP
# 2785        THE WEIR GROUP
#
# [2786 rows x 7 columns]

# %%
print(df.Stock.unique())
st = input("Enter stock Name")
r= df[df.Stock==st]


sb.lineplot(x=r.Date , y=r.Close)
plt.show()
# Out:
# ['ROLLS ROYCE HOLDINGS' 'BAE SYSTEM' 'RELX' 'FERGUSON' 'EXPERIAN'
#  'ASHTEAD GROUP' 'INTERNATION CONS AIRLINES GROUP' 'HALMA'
#  'RENTOKIL INITIAL' 'THE WEIR GROUP']
# Enter stock Name HALMA
